# %%
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set(palette='deep', style='whitegrid')

from sklearn.datasets import load_boston
from sklearn.linear_model import Lasso, Ridge, ElasticNet, LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# Install __[ipywidgets](https://github.com/jupyter-widgets/ipywidgets/blob/master/README.md#install)__ .
#
# Make sure you run
#
#     jupyter nbextension enable --py --sys-prefix widgetsnbextension
#
# in your terminal for the interactive plots to work

# %% [markdown]
# # How changing the polynomial degree $M$ corresponds to the bias-variance tradeoff

# %% [markdown]
# ### What to talk about
# * Bias variance tradeoff caused by higher/lower polynomial degrees

# %%
# %matplotlib notebook
plt.figure(figsize=[10, 6])
def plot_fit(degree=1, seed=1):
    plt.cla()
    n_samples = 30

    np.random.seed(seed)
    true_fun = lambda X: np.sin(np.pi * X)
    X = np.sort(np.random.uniform(high=2, size=n_samples))
    y = true_fun(X) + np.random.randn(n_samples) * 0.1
    
    polynomial_features = PolynomialFeatures(degree=degree, include_bias=False)
    linear_regression = LinearRegression()
    pipeline = Pipeline([("polynomial_features", polynomial_features),
                         ("linear_regression", linear_regression)])
    pipeline.fit(X[:, np.newaxis], y)

    X_test = np.linspace(0, 2, 100)
    plt.plot(X_test, true_fun(X_test), label="True function")
    plt.plot(X_test, pipeline.predict(X_test[:, np.newaxis]), label="Model")
    plt.scatter(X, y, label="Samples")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.xlim((0, 2))
    plt.ylim((-2, 2))
    plt.legend(loc=1)
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
interact(plot_fit, degree=(1, 30, 1), seed=(1, 10, 1));
# Out:
# interactive(children=(IntSlider(value=1, description='degree', max=30, min=1), IntSlider(value=1, description=…

# %% [markdown]
# # How changing the regularization strength $\lambda$ corresponds to the bias-variance tradeoff

# %% [markdown]
# ### What to talk about
# * Bias variance tradeoff caused by higher/lower regularization strength

# %%
# %matplotlib notebook
plt.figure(figsize=[10, 6])
def ridge_polynomial(log_lambda=0, seed=1):
    plt.cla()
    n_samples = 20

    true_fun = lambda X: np.sin(np.pi * X)
    np.random.seed(seed)
    X = np.sort(np.random.uniform(high=2, size=n_samples))
    y = true_fun(X) + np.random.randn(n_samples) * 0.1
    

    polynomial_features = PolynomialFeatures(degree=15, include_bias=False)
    linear_regression = Ridge(alpha=np.power(10, log_lambda))
    pipeline = Pipeline([("polynomial_features", polynomial_features),
                         ("linear_regression", linear_regression)])
    pipeline.fit(X[:, np.newaxis], y)

    X_test = np.linspace(0, 2, 100)
    plt.plot(X_test, true_fun(X_test), label="True function")
    plt.plot(X_test, pipeline.predict(X_test[:, np.newaxis]), label="Model")
    plt.scatter(X, y, label="Samples")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.xlim((0, 2))
    plt.ylim((-2, 2))
    plt.legend(loc=1)
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
interact(ridge_polynomial, log_lambda=(-15, 10, 1.0), seed=(1, 10, 1));
# Out:
# interactive(children=(FloatSlider(value=0.0, description='log_lambda', max=10.0, min=-15.0, step=1.0), IntSlid…

# %% [markdown]
# # Shrinkage with $L_2$ (ridge) and $L_1$ (lasso) regularization

# %% [markdown]
# ### What to talk about
# * Other types of regularization are possible, not necessarily $L_2$, any $L_p$ norm for $p \geq 1$ can be used.
# * Using $0 < p < 1$ leads to nonconvex objective.
# * Using $L_0$ pseudonorm is impossible to optimize with tools discussed in this course, this is called *Compressed sensing* -> entire research discipline.
# * $L_2$ is called **Ridge** leads to smaller values of $\mathbf{w}$ overall, but no entries are equal to 0. Also easier to optimize.
# * $L_1$ is called **Lasso**, leads to sparse $\mathbf{w}$ (lots of entries are equal to 0)
# * You can combine both penalties -> Elastic net
# * http://www.ds100.org/sp17/assets/notebooks/linear_regression/norm_balls.png
# * There exist other regularization schemes, doesn't have to be weight penalty. In general, regularization - decreasing model capacity / increasing bias / reducing variance.

# %%
data = load_boston()
X = data['data']
y = data['target']
names = data['feature_names']

# %%
lambdas = np.logspace(-4, 4, num=100)
# Ridge regression
coefs_ridge = []
for a in lambdas:
    ridge = ElasticNet(alpha=a, l1_ratio=0)
    ridge.fit(X, y)
    coefs_ridge.append(ridge.coef_)
coefs_ridge = np.array(coefs_ridge)

# Lasso
coefs_lasso = []
for a in lambdas:
    lasso = ElasticNet(alpha=a, l1_ratio=1)
    lasso.fit(X, y)
    coefs_lasso.append(lasso.coef_)
coefs_lasso = np.array(coefs_lasso)
# Out:
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5547.761568118927, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5549.412841968333, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5551.375866718163, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5553.703573224446, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5556.455437197973, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5559.697284596205, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5563.500611887723, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5567.9412584897345, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5573.097269806012, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5579.045823454822, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5585.8591749099905, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5593.599726010485, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5602.314534631494, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5612.029849571349, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5622.7465243603765, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5634.437357669705, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5647.047427756802, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5660.498249907258, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5674.6960660711775, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5689.543850663396, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5704.955861430238, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5720.873002761704, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5737.277082102351, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5754.20228480452, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5771.74277423221, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5790.05604195948, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5809.362271770871, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5829.940392330803, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5852.121632230024, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5876.2813021024485, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5902.829301883387, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5932.199581252078, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5964.838545275371, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6001.19225864218, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6041.692323917551, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6086.7405600411, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6136.693137174466, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6191.845611887131, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6252.421197104633, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6318.56527867913, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6390.349240737505, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6467.785736932023, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6550.855578865479, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6639.5437765969855, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6733.87973017106, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6833.975040291703, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6940.052521905327, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7052.461828063903, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7171.680058740751, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7298.298905949411, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7433.002370852691, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7576.5403290207305, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7729.70309502537, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7893.300815018668, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8068.149251149145, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8255.060574128916, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8454.834514642705, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8668.242286502076, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8895.994052778147, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9138.681417507156, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9396.69018979503, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9670.085401166476, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9958.47921197801, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10260.901027661244, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10575.695480657367, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10900.47555852639, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11232.153391468324, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11567.059815927161, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11901.14761060004, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12230.25606789505, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12550.401125520584, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12858.049684032523, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13150.3405744305, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13425.226407316322, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13681.526367621651, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13918.895387981744, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14137.726534266132, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14339.009302739201, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14524.167189366639, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14694.8948833361, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14853.01064256691, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15000.334388689975, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15138.59770537073, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15269.388437554519, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15394.129694079078, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15514.090346523571, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15630.421400414636, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15744.210096857574, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15856.5418154597, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15968.559350865868, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16081.510154535581, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16196.7743861191, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16315.869409399787, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16440.428914197222, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16572.156634714356, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16712.755630684096, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16863.834735355347, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17026.79477551942, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17202.699253638526, tolerance: 4.2716295415019765
#   positive)
# C:\Users\Erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17392.137739500653, tolerance: 4.2716295415019765
#   positive)

# %%
# %matplotlib inline
sns.set(font_scale=2, style='whitegrid')
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=[30, 15])
# Plot ridge
for i in range(13):
    mask = coefs_ridge[:, i] != 0
    ax1.semilogx(lambdas[mask], coefs_ridge[:, i][mask], label=names[i])
ax1.set_xlabel('log $\lambda$ ')
ax1.set_ylabel('Coefficients values')
ax1.set_title('Ridge regression ($L_2$)')
ax1.set_xlim(right=1e4)
ax1.legend()

# Plot lasso
for i in range(13):
    # don't plot the parts where the coefficient is equal to 0
    mask = coefs_lasso[:, i] != 0
    mask[np.where(~mask)[0][0]] = True  
    ax2.semilogx(lambdas[mask], coefs_lasso[:, i][mask], label=names[i])
ax2.set_xlabel('log $\lambda$ ')
ax2.set_title('Lasso ($L_1$)')
ax2.set_xlim(right=1e4)
ax2.legend()
plt.show()

# %% [markdown]
# ### Interpretation of the plots
# The plots show how values of model weights change as regularization scale increases.
#
# In the plots we confirm these facts:
# * $L_2$ leads to smaller values of $\mathbf{w}$ overall, but no entries are equal to 0.
# * $L_1$ leads to sparse $\mathbf{w}$ (lots of entries are equal to 0 as log lambda increases).
# * More on weights regularization in Section 3.4 of https://web.stanford.edu/~hastie/Papers/ESLII.pdf
